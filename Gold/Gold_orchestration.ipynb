# %%
notebooks = [
    "./Gold_dim_customer",
    "./Gold_dim_product",
    "./Gold_fact_sale"
]

print("Starting Gold Layer processing...")
for nb in notebooks:  
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=3600)
print("All Gold notebooks finished successfully!")
