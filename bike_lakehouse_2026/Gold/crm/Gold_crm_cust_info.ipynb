# %% [markdown]
# # Init

# %% [markdown]
# #Read from Silver Table(s)
# *Tables in case of merging multiple tables*
#
# As we define as a rule in the Gold Layer to only use SQL for the logic we wont read the data in a dataframe instead we will be just using the FROM clause in SQL directly in our loigc for reading tables and the output of the query we will put it on a dataframe and writing it back to the gold table

# %% [markdown]
# #Business Transformation and Modeling
# We just need to write a SQL Query to build the model, based on the dseign we have define for the layer

# %% [markdown]
# # Writing Gold Table
